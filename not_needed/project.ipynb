# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
idk = pd.read_csv('Book2.csv', delimiter=',')

idk.head
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 idk = pd.read_csv('Book2.csv', delimiter=',')
#       3 idk.head
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
EdaJob = pd.read_csv('data_utf8.csv')

EdaJob.head(60)
# Out:
#                                                Majors Major Estimated Salary
# 0                               AeroSpace Engineering                  80333  \
# 1                                     ANIMAL SCIENCES                  46000
# 2                                 Applied Mathematics                  57500
# 3                          Architetechural Enineering                 66,000
# 4                                      Architetechure                  51500
# 5                          ASTRONOMY AND ASTROPHYSICS                  71000
# 6                ATMOSPHERIC SCIENCES AND METEOROLOGY                  47500
# 7                                BIOCHEMICAL SCIENCES                  45200
# 8                              BIOLOGICAL ENGINEERING                  59550
# 9                                             BIOLOGY                  49733
# 10                             BIOMEDICAL ENGINEERING                  62500
# ...

# %%
colum_JobTitle = pd.DataFrame(EdaJob,columns=["Job Title"])
colum_JobTitle = colum_JobTitle.to_numpy()

# %%
np.unique(colum_JobTitle)
colum_JobTitle.shape
# Out:
# (740, 1)

# %%
df = pd.read_csv('FInal CSV.csv')

df.head(50)
# Out:
#                                    Job Title  Salary Estimate
# 0                                  Job Title  Salary Estimate  \
# 1                             Data Scientist           72,000
# 2                  Healthcare Data Scientist           88,000
# 3                             Data Scientist           85,000
# 4                             Data Scientist           77,000
# 5                             Data Scientist          115,000
# 6                             Data Scientist           95,000
# 7                             Data Scientist           74,000
# 8                             Data Scientist          114,000
# 9                         Research Scientist           61,000
# 10                            Data Scientist          140,000
# 11                            Data Scientist          164,000
# 12                            Data Scientist           85,000
# 13         Staff Data Scientist - Technology          139,000
# ...

# %%
cm =pd.read_csv('college_majors_and_graduates/recent-grads.csv')

cm.head(150)
# Out:
#      index  Rank  Major_code                                      Major
# 0        0     1        2419                      PETROLEUM ENGINEERING  \
# 1        1     2        2416             MINING AND MINERAL ENGINEERING
# 2        2     3        2415                  METALLURGICAL ENGINEERING
# 3        3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4        4     5        2405                       CHEMICAL ENGINEERING
# ..     ...   ...         ...                                        ...
# 145    145   146        5200                                 PSYCHOLOGY
# 146    146   147        6002                                      MUSIC
# 147    147   148        2306     PHYSICAL AND HEALTH EDUCATION TEACHING
# 148    148   149        6006                  ART HISTORY AND CRITICISM
# 149    149   150        6000                                  FINE ARTS
#
#                 Major_category   Total  Sample_size    Men   Women
# ...

# %%
er =pd.read_csv('college_majors_and_graduates/women-stem.csv')

er.head(30)
# Out:
#     index  Rank  Major_code
# 0       0     1        2419  \
# 1       1     2        2416
# 2       2     3        2415
# 3       3     4        2417
# 4       4     5        2418
# 5       5     6        2405
# 6       6     7        5001
# 7       7     8        2414
# 8       8     9        2401
# 9       9    10        2408
# 10     10    11        2407
# 11     11    12        5008
# 12     12    13        2404
# 13     13    14        2409
# 14     14    15        2402
# 15     15    16        2412
# 16     16    17        2400
# 17     17    18        2403
# 18     18    19        2102
# 19     19    20        2502
# 20     20    21        2413
# 21     21    22        2499
# 22     22    23        2406
# 23     23    24        2500
# 24     24    25        2411
# 25     25    26        2410
# 26     26    27        6107
# 27     27    28        2503
# 28     28    29        5102
# 29     29    30        2105
#
#                                                 Major
# ...

# %%
laiv =pd.read_csv('LAI/Affordability Index Virginia.csv')
laic =pd.read_csv('LAI/Affordability Index California.csv')
laif =pd.read_csv('LAI/Affordability Index Florida.csv')
lainy =pd.read_csv('LAI/Affordability Index New York.csv')
lait =pd.read_csv('LAI/Affordability Index Texas.csv')

# %%
laif.head(20)
# Out:
#             blkgrp  households  area_median_income
# 0   '120010002001'       310.0             42311.0  \
# 1   '120010002002'       223.0             42311.0
# 2   '120010002003'       370.0             42311.0
# 3   '120010002004'       361.0             42311.0
# 4   '120010002005'       351.0             42311.0
# 5   '120010002006'       769.0             42311.0
# 6   '120010003011'       725.0             42311.0
# 7   '120010003012'       866.0             42311.0
# 8   '120010003021'       127.0             42311.0
# 9   '120010003022'       496.0             42311.0
# 10  '120010003023'       651.0             42311.0
# 11  '120010004001'       422.0             42311.0
# 12  '120010004002'       450.0             42311.0
# 13  '120010004003'       400.0             42311.0
# 14  '120010004004'       670.0             42311.0
# 15  '120010005001'       781.0             42311.0
# 16  '120010005002'       342.0             42311.0
# ...

# %%
feature1 = pd.DataFrame(laiv,columns=["area_median_income"])
 
feature1
# Out:
#       area_median_income
# 0                40780.0
# 1                40780.0
# 2                40780.0
# 3                40780.0
# 4                40780.0
# ...                  ...
# 5374             51815.0
# 5375             51815.0
# 5376             51815.0
# 5377             51815.0
# 5378             51815.0
#
# [5379 rows x 1 columns]

# %%
general_data = pd.DataFrame(columns=["States","Major","Major income salary","Area"])
general_data.ag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31160\1843793633.py in ?()
#       1 general_data = pd.DataFrame(columns=["States","Major","Major income salary","Area"])
# ----> 2 general_data.ag
#
# ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ag'

# %%
plt.plot(x1,y1,x2,y2,)

# %%
InterJob.info()
InterJob.isna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40061 entries, 0 to 40060
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Job-Title    40061 non-null  object
#  1   Date-Posted  30207 non-null  object
#  2   Company      40057 non-null  object
#  3   Job-Type     37495 non-null  object
#  4   Salary       2429 non-null   object
#  5   Location     40061 non-null  object
#  6   Description  40061 non-null  object
# dtypes: object(7)
# memory usage: 2.1+ MB
#        Job-Title  Date-Posted  Company  Job-Type  Salary  Location
# 0          False        False    False     False    True     False  \
# 1          False        False    False     False    True     False
# 2          False        False    False     False   False     False
# 3          False        False    False     False    True     False
# 4          False        False    False     False    True     False
# ...
